# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import glob
files = glob.glob("snap/*.csv")
itr = iter(files)

# %%
#path = next(itr)
path = "snap/snap.10117.csv"
df = pd.read_csv(path,header=None)
plt.scatter(df[0],-df[1],s=100)
#plt.figure(figsize=(4,2))
plt.rcParams['figure.figsize'] = [15, 5]
