# %%
using Plots
using DelimitedFiles

# %%
files = readdir("snap/")
i = 1
# Out:
# 1

# %%
a = readdlm("snap/" * files[i], ',', Int)
i += 1
plot(a[:,1],a[:,2],seriestype=:scatter)
# Out:
# BoundsError: attempt to access 42-element Array{String,1} at index [43]
#
# Stacktrace:
#  [1] getindex(::Array{String,1}, ::Int64) at ./array.jl:744
#  [2] top-level scope at In[79]:1

# %%
b = readdlm("t1", ' ', Int)
plot(b)
